# %%
# Step 1: Import Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Step 2: Load Dataset (created earlier)
df = pd.read_csv('Pakistan_Unemployment.csv')
print("🔹 First 5 rows:\n", df.head())

# Step 3: Check Info & Summary
print("\n🔹 Dataset Info:")
print(df.info())

print("\n🔹 Null Values:\n", df.isnull().sum())

# Step 4: Unemployment Trend Over Time
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x='Year', y='Unemployment Rate', marker='o', color='darkblue')
plt.title('Unemployment Rate in Pakistan (2000–2023)', fontsize=14)
plt.xlabel('Year')
plt.ylabel('Unemployment Rate (%)')
plt.grid(True)
plt.tight_layout()
plt.show()

# Step 5: Correlation Heatmap
plt.figure(figsize=(6, 5))
sns.heatmap(df.corr(), annot=True, cmap='Purples')
plt.title('Correlation Matrix')
plt.tight_layout()
plt.show()
# Out:
# 🔹 First 5 rows:
#     Year  Unemployment Rate  Population
# 0  2000                7.9         140
# 1  2001                7.8         143
# 2  2002                7.5         146
# 3  2003                7.2         149
# 4  2004                7.1         152
#
# 🔹 Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               24 non-null     int64
#  1   Unemployment Rate  24 non-null     float64
#  2   Population         24 non-null     int64
# dtypes: float64(1), int64(2)
# memory usage: 708.0 bytes
# None
#
# 🔹 Null Values:
#  Year                 0
# Unemployment Rate    0
# Population           0
# dtype: int64
